# %% [markdown]
# Seguint les reges a: http://sramatic.tripod.com/silabas.html

# %%
class char():
    def __init__(self):
        pass
    
class char_line():
    def __init__(self, word):
        self.word = word
        self.char_line = [(char, self.char_type(char)) for char in word]
        self.type_line = ''.join(chartype for char, chartype in self.char_line)
        
    def char_type(self, char):
        if char in set(['a', 'á', 'e', 'é','o', 'ó', 'í', 'ú']):
            return 'V' #strong vowel
        if char in set(['i', 'u']):
            return 'v' #week vowel
        if char=='x':
            return 'x'
        if char=='s':
            return 's'
        else:
            return 'c'
            
    def find(self, finder):
        return self.type_line.find(finder)
        
    def split(self, pos, where):
        return char_line(self.word[0:pos+where]), char_line(self.word[pos+where:])
    
    def split_by(self, finder, where):
        split_point = self.find(finder)
        if split_point!=-1:
            chl1, chl2 = self.split(split_point, where)
            return chl1, chl2
        return self, False
     
    def __str__(self):
        return '<'+self.word+':'+self.type_line+'>'
    
    def __repr__(self):
        return '<'+repr(self.word)+':'+self.type_line+'>'

class silabizer():
    def __init__(self):
        self.grammar = []
        
    def split(self, chars):
        rules  = [('VV',1), ('cccc',2), ('xcc',1), ('ccx',2), ('csc',2), ('xc',1), ('cc',1), ('vcc',2), ('Vcc',2), ('sc',1), ('cs',1),('Vc',1), ('vc',1), ('Vs',1), ('vs',1), ('vxv',1), ('VxV',1), ('vxV',1), ('Vxv',1)]
        for split_rule, where in rules:
            first, second = chars.split_by(split_rule,where)
            if second:
                if first.type_line in set(['c','s','x','cs']) or second.type_line in set(['c','s','x','cs']):
                    #print 'skip1', first.word, second.word, split_rule, chars.type_line
                    continue
                if first.type_line[-1]=='c' and second.word[0] in set(['l','r']):
                    continue
                if first.word[-1]=='l' and second.word[-1]=='l':
                    continue
                if first.word[-1]=='r' and second.word[-1]=='r':
                    continue
                if first.word[-1]=='c' and second.word[-1]=='h':
                    continue
                return self.split(first)+self.split(second)
        return [chars]
        
    def __call__(self, word):
        return self.split(char_line(word))

# %%
from __future__ import unicode_literals

s = silabizer()

print s('ola') ,'o-la'
print s('amor') ,'a-mor'
print s('usual') ,'u-sual'
print s('caos') ,'ca-os'
print s('leo') ,'le-o'
print s('traer') ,'tra-er'
print s('extraordinario') ,'ex-tra-or-di-na-rio'
print s('inscribir') ,'ins-cri-bir'
print s('constante') ,'cons-tan-te'
print s('inspector') ,'ins-pec-tor'
print s('experto') ,'ex-per-to'
print s('aire') ,'ai-re'
print s('ciudad') ,'ciu-dad'
print s('pie') ,'pie'
print s('tomate') ,'to-ma-te'
print s('amigo') ,'a-mi-go'
print s('camiseta') ,'ca-mi-se-ta'
print s('acción') ,'ac-ción'
print s('también') ,'tam-bién'
print s('cansado') ,'can-sa-do'
print s('frío') ,'frí-o'
print s('hablar') ,'ha-blar'
print s('problema') ,'pro-ble-ma'
print s('chico') ,'chi-co'
print s('tortilla') ,'tor-ti-lla'
print s('arroz') ,'a-rroz'
print s('increíble') ,'in-cre-í-ble'
print s('improvisar') ,'im-pro-vi-sar'
print s('esdrújula') ,'es-drú-ju-la'
print s('difíciles') ,'di-fí-ci-les'
print s('atar') ,'a-tar'
print s('hielo') ,'hie-lo'
print s('casa') ,'ca-sa'
print s('cielo') ,'cie-lo'
print s('aceite') ,'a-cei-te'
print s('buey') ,'buey'
print s('trono') ,'tro-no'
print s('trueno') ,'true-no'
print s('pleito') ,'plei-to'
print s('alto') ,'al-to'
print s('instrucción') ,'ins-truc-ción'
print s('hierba') ,'hier-ba'
print s('austero') ,'aus-te-ro'
print s('cinta') ,'cin-ta'
print s('constreñir') ,'cons-tre-ñir'
print s('cuento') ,'cuen-to'
print s('veinte') ,'vein-te'
print s('averiguáis') ,'a-ve-ri-guáis'
print s('tronco'),'tron-co'
print s('transporte') ,'trans-por-te'
print s('triente') ,'trien-te'
print s('trienta') ,'trien-ta'
print s('agriáis') ,'a-griais'
print s('sílabas') ,'sí-la-bas'
print s('águila') ,'á-gui-la'
# Out:
# [<u'o':V>, <u'la':cV>] o-la
# [<u'a':V>, <u'mor':cVc>] a-mor
# [<u'u':v>, <u'sual':svVc>] u-sual
# [<u'ca':cV>, <u'os':Vs>] ca-os
# [<u'le':cV>, <u'o':V>] le-o
# [<u'tra':ccV>, <u'er':Vc>] tra-er
# [<u'ex':Vx>, <u'tra':ccV>, <u'or':Vc>, <u'di':cv>, <u'na':cV>, <u'rio':cvV>] ex-tra-or-di-na-rio
# [<u'ins':vcs>, <u'cri':ccv>, <u'bir':cvc>] ins-cri-bir
# [<u'cons':cVcs>, <u'tan':cVc>, <u'te':cV>] cons-tan-te
# [<u'ins':vcs>, <u'pec':cVc>, <u'tor':cVc>] ins-pec-tor
# [<u'ex':Vx>, <u'per':cVc>, <u'to':cV>] ex-per-to
# [<u'ai':Vv>, <u're':cV>] ai-re
# [<u'ciu':cvv>, <u'dad':cVc>] ciu-dad
# [<u'pie':cvV>] pie
# [<u'to':cV>, <u'ma':cV>, <u'te':cV>] to-ma-te
# [<u'a':V>, <u'mi':cv>, <u'go':cV>] a-mi-go
# [<u'ca':cV>, <u'mi':cv>, <u'se':sV>, <u'ta':cV>] ca-mi-se-ta
# [<u'ac':Vc>, <u'ci':cv>, <u'\xf3n':cc>] ac-ción
# [<u'tam':cVc>, <u'bi':cv>, <u'\xe9n':cc>] tam-bién
# [<u'can':cVc>, <u'sa':sV>, <u'do':cV>] can-sa-do
# [<u'fr\xedo':cccV>] frí-o
# [<u'ha':cV>, <u'blar':ccVc>] ha-blar
# [<u'pro':ccV>, <u'ble':ccV>, <u'ma':cV>] pro-ble-ma
# [<u'chi':ccv>, <u'co':cV>] chi-co
# [<u'tor':cVc>, <u'ti':cv>, <u'lla':ccV>] tor-ti-lla
# [<u'a':V>, <u'rroz':ccVc>] a-rroz
# [<u'in':vc>, <u'cre\xed':ccVc>, <u'ble':ccV>] in-cre-í-ble
# [<u'im':vc>, <u'pro':ccV>, <u'vi':cv>, <u'sar':sVc>] im-pro-vi-sar
# [<u'es':Vs>, <u'dr':cc>, <u'\xfaju':ccv>, <u'la':cV>] es-drú-ju-la
# [<u'dif':cvc>, <u'\xedci':ccv>, <u'les':cVs>] di-fí-ci-les
# [<u'a':V>, <u'tar':cVc>] a-tar
# [<u'hie':cvV>, <u'lo':cV>] hie-lo
# [<u'ca':cV>, <u'sa':sV>] ca-sa
# [<u'cie':cvV>, <u'lo':cV>] cie-lo
# [<u'a':V>, <u'cei':cVv>, <u'te':cV>] a-cei-te
# [<u'buey':cvVc>] buey
# [<u'tro':ccV>, <u'no':cV>] tro-no
# [<u'true':ccvV>, <u'no':cV>] true-no
# [<u'plei':ccVv>, <u'to':cV>] plei-to
# [<u'al':Vc>, <u'to':cV>] al-to
# [<u'ins':vcs>, <u'truc':ccvc>, <u'ci':cv>, <u'\xf3n':cc>] ins-truc-ción
# [<u'hier':cvVc>, <u'ba':cV>] hier-ba
# [<u'aus':Vvs>, <u'te':cV>, <u'ro':cV>] aus-te-ro
# [<u'cin':cvc>, <u'ta':cV>] cin-ta
# [<u'cons':cVcs>, <u'tre':ccV>, <u'\xf1ir':cvc>] cons-tre-ñir
# [<u'cuen':cvVc>, <u'to':cV>] cuen-to
# [<u'vein':cVvc>, <u'te':cV>] vein-te
# [<u'a':V>, <u've':cV>, <u'ri':cv>, <u'gu':cv>, <u'\xe1is':cvs>] a-ve-ri-guáis
# [<u'tron':ccVc>, <u'co':cV>] tron-co
# [<u'trans':ccVcs>, <u'por':cVc>, <u'te':cV>] trans-por-te
# [<u'trien':ccvVc>, <u'te':cV>] trien-te
# [<u'trien':ccvVc>, <u'ta':cV>] trien-ta
# [<u'a':V>, <u'gri':ccv>, <u'\xe1is':cvs>] a-griais
# [<u's\xedla':sccV>, <u'bas':cVs>] sí-la-bas
# [<u'\xe1gui':ccvv>, <u'la':cV>] á-gui-la

# %%
print s('analizar')
# Out:
# [<u'a':V>, <u'na':cV>, <u'li':cv>, <u'zar':cVc>]
